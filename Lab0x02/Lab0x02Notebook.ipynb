# %% [markdown]
# Noah Tanner, Kosimo Tonn
# Lab 0x02 - ME405
# Fall 2023

# %%
from matplotlib import pyplot
import math

x_values = []
t_values = []
v_values = []

file = open('data.csv', mode='r')

for line in file:
    x = float(data[0])
    t = float(data[1])
    v = float(data[2])
    x_values.append(x)
    t_values.append(t)
    v_values.append(v)

pyplot.plot (t_values, v_values)
pyplot.title("Velocity (RPM) vs. Time (s)")
pyplot.ylabel("Velocity(RPM)")
pyplot.xlabel("Time (s)")
pyplot.grid(True)
pyplot.show()

pyplot.plot (t_values, x_values)
pyplot.title("Position vs. Time (s)")
pyplot.ylabel("Position")
pyplot.xlabel("Time (s)")
pyplot.grid(True)
pyplot.show()

pyplot.plot (t_values, log(1-v_values/(max(v_values)+0.001)))
pyplot.title("vs. Time (s)")
pyplot.ylabel("Velocity(RPM)")
pyplot.xlabel("Time (s)")
pyplot.grid(True)
pyplot.show()
