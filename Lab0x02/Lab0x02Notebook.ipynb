# %% [markdown]
# Noah Tanner, Kosimo Tonn
# Lab 0x02 - ME405
# Fall 2023

# %%
import main, motor_class_main as mot

# initialize and begin data collection with motor A using a 100% duty cyce
main.collector_1.start(mot.mot_A, 100)
